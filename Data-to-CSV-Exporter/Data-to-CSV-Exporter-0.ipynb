# %%
file = 'housing.data'

f = open(file, "r")

a = [list(filter(lambda x: x!='', re.split(r"\s+", line))) for line in f]

a.insert(0, ['CRIM',
'ZN',
'INDUS',
'CHAS',
'NOX',
'RM',
'AGE',
'DIS',
'RAD',
'TAX',
'PTRATIO',
'B',
'LSTAT',
'MEDV'])

csv_str = '\n'.join([sep.join(x) for x in a])

f = open(file+".csv", "w")
f.write(csv_str)
f.close()
